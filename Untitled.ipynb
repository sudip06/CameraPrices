# %%
import os
import matplotlib
import pandas as pd
import seaborn
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display

# %%
if os.name == 'nt':
    os.chdir("C:\sudip\Download")
elif os.name == 'posix':
    os.chdir("/home/sudip/myProjects/machineLearning/pandas/pandasDataset/")

# %%
#df=pd.read_csv("Camera.csv",delimiter=";")
df=pd.read_csv("Camera.csv",delimiter=";")

# %%
df.Price=pd.to_numeric(df.Price,errors='coerce')
df.loc[df.Price.isnull()==True]
# Out:
#     Model Release date Max resolution Low resolution Effective pixels  \
# 0  STRING       DOUBLE         DOUBLE         DOUBLE           DOUBLE
#
#   Zoom wide (W) Zoom tele (T) Normal focus range Macro focus range  \
# 0        DOUBLE        DOUBLE             DOUBLE            DOUBLE
#
#   Storage included Weight (inc. batteries) Dimensions  Price
# 0           DOUBLE                  DOUBLE     DOUBLE    NaN

# %%
#df=pd.read_csv("Camera.csv",delimiter=";",skiprows=[1],converters={'Price':float,'Max resolution':float,'Low resolution':float, 'Effective pixels':float, 'Zoom wide (W)':float,'Zoom tele (T)':float, 'Normal focus range':float,'Macro focus range':float, 'Storage included':float, 'Weight (inc. batteries)':float, 'Dimensions':float,'Price':float})
df=pd.read_csv("Camera.csv",delimiter=";",skiprows=[1],converters={'Price':float,'Max resolution':float,'Low resolution':float, 'Effective pixels':float, 'Zoom wide (W)':float,'Zoom tele (T)':float, 'Normal focus range':float,'Price':float})
df.describe()
# Out:
#        Release date  Max resolution  Low resolution  Effective pixels  \
# count   1038.000000     1038.000000     1038.000000       1038.000000
# mean    2003.590559     2474.672447     1773.936416          4.596339
# std        2.724755      759.513608      830.897955          2.844044
# min     1994.000000        0.000000        0.000000          0.000000
# 25%     2002.000000     2048.000000     1120.000000          3.000000
# 50%     2004.000000     2560.000000     2048.000000          4.000000
# 75%     2006.000000     3072.000000     2560.000000          7.000000
# max     2007.000000     5616.000000     4992.000000         21.000000
#
#        Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# count    1038.000000    1038.000000         1038.000000        1037.000000
# mean       32.963391     121.525048           44.145472           7.787850
# std        10.333149      93.455422           24.141959           8.100081
# ...

# %%
df.columns
# Out:
# Index(['Model', 'Release date', 'Max resolution', 'Low resolution',
#        'Effective pixels', 'Zoom wide (W)', 'Zoom tele (T)',
#        'Normal focus range', 'Macro focus range', 'Storage included',
#        'Weight (inc. batteries)', 'Dimensions', 'Price'],
#       dtype='object')

# %%
df.isnull().any()
# Out:
# Model                      False
# Release date               False
# Max resolution             False
# Low resolution             False
# Effective pixels           False
# Zoom wide (W)              False
# Zoom tele (T)              False
# Normal focus range         False
# Macro focus range           True
# Storage included            True
# Weight (inc. batteries)     True
# Dimensions                  True
# Price                      False
# dtype: bool

# %%
df.index.is_unique
# Out:
# True

# %%
df['Effective pixels'].unique()
# Out:
# array([ 0.,  1.,  3.,  4.,  5.,  6.,  7.,  8., 10., 12., 11., 16., 21.,
#         2.,  9., 13.])

# %%
df.groupby(['Effective pixels','Model'],sort=True).head(2)
# Out:
#                        Model  Release date  Max resolution  Low resolution  \
# 0           Agfa ePhoto 1280          1997          1024.0           640.0
# 1           Agfa ePhoto 1680          1998          1280.0           640.0
# 2           Agfa ePhoto CL18          2000           640.0             0.0
# 3           Agfa ePhoto CL30          1999          1152.0           640.0
# 4     Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# 5           Agfa ePhoto CL45          2001          1600.0           640.0
# 6           Agfa ePhoto CL50          1999          1280.0           640.0
# 7        Canon PowerShot 350          1997           640.0             0.0
# 8        Canon PowerShot 600          1996           832.0           640.0
# 9        Canon PowerShot A10          2001          1280.0          1024.0
# 10      Canon PowerShot A100          2002          1280.0          1024.0
# ...

# %%
df.columns
# Out:
# Index(['Model', 'Release date', 'Max resolution', 'Low resolution',
#        'Effective pixels', 'Zoom wide (W)', 'Zoom tele (T)',
#        'Normal focus range', 'Macro focus range', 'Storage included',
#        'Weight (inc. batteries)', 'Dimensions', 'Price'],
#       dtype='object')

# %%
#df.groupby(['Max resolution']).agg(['Price':'mean']).head()
df.groupby(['Max resolution']).size().sort_values(ascending=False).head()
# Out:
# Max resolution
# 3072.0    108
# 2048.0    102
# 1600.0     83
# 3264.0     73
# 2816.0     68
# dtype: int64

# %%
df2=df.groupby(['Max resolution']).agg({'Price':['mean'],'Max resolution':['count']})
level0=df2.columns.get_level_values(0)
level1=df2.columns.get_level_values(1)
print (level0)
print (level1)
df2.columns=level0+"_"+level1
df2.reset_index(inplace=True)
# Out:
# Index(['Max resolution', 'Price'], dtype='object')
# Index(['count', 'mean'], dtype='object')

# %%
df2.columns
_,_= plt.subplots(figsize=(20, 10))
#sns.jointplot(x='Max resolution', y='Price_mean', data=df2,kind="kde")
#sns.barplot(x='Max resolution', y='Price_mean',data=df2)
sns.swarmplot(x='Max resolution', y='Price_mean',data=df2)
plt.show()

# %%
df['Effective pixels'].isnull().any()
# Out:
# False

# %%
df2=df.groupby(['Effective pixels','Release date'])['Price'].agg(['mean','count','sum'])
#display(df.groupby(['Effective pixels','Release date'])['Price'].agg('mean').head(7))
level0=df2.columns.get_level_values(0)
#level1=df2.columns.get_level_values(1)
print (level0)
#print (level1)
df2.columns='Price'+"_"+level0
df2.reset_index(inplace=True)

_,_= plt.subplots(figsize=(12, 7))

    #sns.jointplot(x='Max resolution', y='Price_mean', data=df2,kind="kde")
    #sns.barplot(x='Effective pixels', y='Price_mean',hue='Release date',data=df2)
sns.barplot(x='Effective pixels', y='Price_mean',hue='Release date',data=df2)
plt.show()
# Out:
# Index(['mean', 'count', 'sum'], dtype='object')

# %%
df.columns
# Out:
# Index(['Model', 'Release date', 'Max resolution', 'Low resolution',
#        'Effective pixels', 'Zoom wide (W)', 'Zoom tele (T)',
#        'Normal focus range', 'Macro focus range', 'Storage included',
#        'Weight (inc. batteries)', 'Dimensions', 'Price'],
#       dtype='object')

# %%
####So, let's see if we can apply some machine language here to predict the prices We know, prices varies across brands,
# hence we segregate it across brands
df['Model']=df['Model'].str.split().str[0]
df.groupby(['Model'])['Model'].size() #how many models per brand('Oops: Sony released 116 models compared to Kodak's 102, hmmm)
# Out:
# Model
# Agfa           7
# Canon        115
# Casio         63
# Contax         2
# Epson         15
# Fujifilm      99
# HP            46
# JVC            2
# Kodak        102
# Kyocera       15
# Leica         11
# Nikon         90
# Olympus      122
# Panasonic     55
# Pentax        68
# Ricoh         26
# Samsung       54
# Sanyo          8
# Sigma          4
# Sony         116
# Toshiba       18
# Name: Model, dtype: int64

# %%
#WTF!!!Its clear camera with max effective pixels 21 is the costiliest. Lets check the features, just 
#personal interest.
df['Effective pixels'].dtype
df[df['Effective pixels']>16]
# Out:
#     Model  Release date  Max resolution  Low resolution  Effective pixels  \
# 54  Canon          2007          5616.0          4992.0              21.0
#
#     Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# 54            0.0            0.0                 0.0                0.0
#
#     Storage included  Weight (inc. batteries)  Dimensions   Price
# 54               0.0                   1385.0       150.0  7999.0

# %%
from sklearn import preprocessing

# %%
#display(df.groupby(['Release date']).size())
df['Release date'].value_counts()
# Out:
# 2007    163
# 2006    153
# 2005    143
# 2004    141
# 2003    101
# 2002     89
# 2001     85
# 2000     61
# 1999     53
# 1998     32
# 1997     11
# 1996      4
# 1995      1
# 1994      1
# Name: Release date, dtype: int64

# %%
sns.barplot(x=df['Release date'].value_counts().index,y=df['Release date'].value_counts(),color='blue')
plt.show()

# %%
df.dtypes
# Out:
# Model                       object
# Release date                 int64
# Max resolution             float64
# Low resolution             float64
# Effective pixels           float64
# Zoom wide (W)              float64
# Zoom tele (T)              float64
# Normal focus range         float64
# Macro focus range          float64
# Storage included           float64
# Weight (inc. batteries)    float64
# Dimensions                 float64
# Price                      float64
# dtype: object

# %%
df['Storage included'].unique()
# Out:
# array([  4.,   2.,  40.,   8.,   1.,  32.,   0.,  16.,  64.,   7.,   9.,
#         10.,  11.,  15.,   6.,  12.,  26.,  25.,  27., 340.,  58.,  54.,
#         nan,  22.,  20., 256.,  24.,  13.,  14.,  21.,  23.,  52.,  28.,
#         48.,  47.,  19.,  17.,  18.,  50.,  45., 450., 173., 128.,  31.,
#         56.])

# %%
df['Dimensions'].unique()
# Out:
# array([ 95. , 158. ,   0. , 128. , 119. ,  93. , 160. , 110. , 111. ,
#        107. , 103. , 106. , 105. ,  91. ,  90. , 101. , 109. ,  97. ,
#         94. ,  98. , 150. , 156. , 144. , 142. , 127. , 146. , 152. ,
#        120. , 121. , 118. , 148. ,  87. , 113. , 112. , 117. , 114. ,
#        104. ,  85. ,  86. ,  96. ,  99. ,  92. ,  89. ,  88. ,  83. ,
#         94.5, 130. , 108. ,  67. ,  81. , 115. , 162. , 134. , 147. ,
#        131. , 141. , 129. , 143. , 135. ,  85.5, 100. , 153. , 125. ,
#         80. , 102. ,  77. ,  75. ,  72. ,  65. ,  74. ,  79. ,  78. ,
#        123. , 122. , 240. , 126. , 124. ,   nan,  84. , 133. , 140. ,
#        137. , 170. , 161. , 194. , 116. ,  38. ,  30. ,  32. , 139. ,
#         60. ,  95.5,  99.5, 157. , 138. , 132. , 145. , 136. ,  54. ,
#         82. ,  73. ,  51. ])

# %%
df.loc[df['Macro focus range'].isnull()==True]
# Out:
#     Model  Release date  Max resolution  Low resolution  Effective pixels  \
# 346    HP          2007          3298.0             0.0               8.0
#
#      Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# 346           39.0          118.0                50.0                NaN
#
#      Storage included  Weight (inc. batteries)  Dimensions  Price
# 346               NaN                      NaN         NaN  179.0

# %%
df.loc[df['Storage included'].isnull()==True]
# Out:
#     Model  Release date  Max resolution  Low resolution  Effective pixels  \
# 345    HP          2006          3296.0          2592.0               8.0
# 346    HP          2007          3298.0             0.0               8.0
#
#      Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# 345           35.0          105.0                50.0               10.0
# 346           39.0          118.0                50.0                NaN
#
#      Storage included  Weight (inc. batteries)  Dimensions  Price
# 345               NaN                      NaN         NaN  179.0
# 346               NaN                      NaN         NaN  179.0

# %%
df.loc[df['Weight (inc. batteries)'].isnull()==True]
# Out:
#     Model  Release date  Max resolution  Low resolution  Effective pixels  \
# 345    HP          2006          3296.0          2592.0               8.0
# 346    HP          2007          3298.0             0.0               8.0
#
#      Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# 345           35.0          105.0                50.0               10.0
# 346           39.0          118.0                50.0                NaN
#
#      Storage included  Weight (inc. batteries)  Dimensions  Price
# 345               NaN                      NaN         NaN  179.0
# 346               NaN                      NaN         NaN  179.0

# %%
df.loc[df['Dimensions'].isnull()==True]
# Out:
#     Model  Release date  Max resolution  Low resolution  Effective pixels  \
# 345    HP          2006          3296.0          2592.0               8.0
# 346    HP          2007          3298.0             0.0               8.0
#
#      Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# 345           35.0          105.0                50.0               10.0
# 346           39.0          118.0                50.0                NaN
#
#      Storage included  Weight (inc. batteries)  Dimensions  Price
# 345               NaN                      NaN         NaN  179.0
# 346               NaN                      NaN         NaN  179.0

# %%
#df.loc[(df['HP'](df['Release date'].isin(['2006','2007'])]
#df.loc[(df['Model']=='HP') & (df['Release date'].isin(['2006','2007']))]
#df.loc[(df['Model']=='HP') & (df['Release date']=='2007')]
df[(df['Model'] == 'HP') & (df['Release date'].isin(['2007']))]
# Out:
#     Model  Release date  Max resolution  Low resolution  Effective pixels  \
# 322    HP          2007          2576.0             0.0               5.0
# 329    HP          2007          2576.0             0.0               5.0
# 333    HP          2007          2848.0             0.0               6.0
# 334    HP          2007          3264.0             0.0               8.0
# 341    HP          2007          3096.0             0.0               7.0
# 344    HP          2007          3112.0             0.0               7.0
# 346    HP          2007          3298.0             0.0               8.0
#
#      Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# 322           36.0           36.0               100.0                0.0
# 329           38.0          114.0                50.0               10.0
# 333           38.0          114.0                50.0                0.0
# 334           35.0          210.0                 0.0               14.0
# ...

# %%
df[(df['Model'] == 'HP') & (df['Release date'].isin(['2006']))]
# Out:
#     Model  Release date  Max resolution  Low resolution  Effective pixels  \
# 321    HP          2006          2560.0          2048.0               5.0
# 328    HP          2006          2576.0          2080.0               5.0
# 331    HP          2006          2800.0          2288.0               6.0
# 332    HP          2006          2800.0          2288.0               6.0
# 339    HP          2006          2864.0          2592.0               6.0
# 340    HP          2006          2864.0          2592.0               6.0
# 345    HP          2006          3296.0          2592.0               8.0
#
#      Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# 321           35.0           35.0                60.0                0.0
# 328           38.0          114.0                50.0               12.0
# 331           38.0          114.0                50.0               12.0
# 332           38.0          114.0                50.0               12.0
# ...

# %%
df['Macro focus range'] = df.groupby(['Model','Release date'])['Macro focus range'].apply(lambda x: x.fillna(x.mean()))

# %%
df.isnull().sum()
# Out:
# Model                      0
# Release date               0
# Max resolution             0
# Low resolution             0
# Effective pixels           0
# Zoom wide (W)              0
# Zoom tele (T)              0
# Normal focus range         0
# Macro focus range          0
# Storage included           2
# Weight (inc. batteries)    2
# Dimensions                 2
# Price                      0
# dtype: int64

# %%
df['Storage included'] = df.groupby(['Model','Release date'])['Storage included'].apply(lambda x: x.fillna(x.mean()))

# %%
df['Weight (inc. batteries)'] = df.groupby(['Model','Release date'])['Weight (inc. batteries)'].apply(lambda x: x.fillna(x.mean()))

# %%
df['Dimensions'] = df.groupby(['Model','Release date'])['Dimensions'].apply(lambda x: x.fillna(x.mean()))

# %%
df.isnull().any().any()
# Out:
# False

# %%
dfMod=pd.get_dummies(df,columns=['Model'])
display(np.shape(dfMod))
# Out:
# (1038, 33)

# %%
X=dfMod.loc[:,dfMod.columns!='Price']
Y=dfMod['Price']

# %%
from sklearn.model_selection import train_test_split
train_X,val_X, train_Y,val_Y=train_test_split(X,Y, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
forest_model=RandomForestRegressor()
forest_model.fit(train_X,train_Y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
from sklearn.metrics import mean_absolute_error
melb_preds=forest_model.predict(val_X)
print(mean_absolute_error(val_Y,melb_preds))
# Out:
# 148.22064102564104

# %%
#my_list = map(lambda x: x[0], melb_preds)

# %%
#type(my_list)

# %%
df['Price'].isnull().any()
# Out:
# False

# %%
val_Y=val_Y.reset_index()

# %%
compareDf=pd.concat([val_Y, pd.Series(melb_preds.reshape(260))], axis=1,ignore_index=True)

# %%
display (compareDf.head(5))
# Out:
#      0      1      2
# 0  597  449.0  449.0
# 1  822  399.0  107.0
# 2   97  199.0  226.0
# 3   75  399.0  156.0
# 4  249  199.0  180.8

# %%
compareDf.drop(columns=0,inplace=True)

# %%
display(compareDf.head())
# Out:
#        1      2
# 0  449.0  449.0
# 1  399.0  107.0
# 2  199.0  226.0
# 3  399.0  156.0
# 4  199.0  180.8

# %%
#plt.figure(figsize=(30,20))
plt.rcParams["figure.figsize"] = (20,10)
compareDf.plot.bar(x=c2.index)
plt.show()
